# %%
import pickle

# %%
data = pickle.load(open('Capstone_parsed.pick','rb'))

# %%
print(data['cornerstone']['allcompanies'])
# Out:
# ['discoverycommunications' 'lbrands' 'aspentechnology' 'fireeye'
#  'intersections' 'entegris' 'bioscrip' 'rambus' 'mellanoxtechnologies'
#  'bedbath&beyond' 'gamingandleisureproperties' 'fiveprimetherapeutics'
#  'celldextherapeutics' 'alliancehealthcareservices' 'apple'
#  'pattersoncompanies' 'amerisafe' 'waterscorporation'
#  'iderapharmaceuticals' 'endologix' "papajohn'sinternational"
#  'fultonfinancialcorporation' 'nasdaq' 'insuletcorporation'
#  'olddominionfreightline' 'sproutsfarmersmarket' 'sagetherapeutics'
#  'stamps.com' 'quantaservices' 'fuelcellenergy' 'unitedhealthgroup'
#  'tetraphasepharmaceuticals' 'advaxis' 'patrickindustries' 'hibbettsports'
#  'dermira' 'myriadgenetics' 'viacom' 'alimerasciences'
#  'federalrealtyinvestmenttrust' 'foundationmedicine' 'jackinthebox' 'visa'
#  'five9' 'rockwellcollins' 'forresterresearch' 'fmccorporation'
#  'thebancorp' 'mattersightcorporation' 'lemaitrevascular' 'qad'
# ...

# %%
import DI_Capstone_plots as dcp

# %%
plotter = dcp.Plotter(data)

# %%
plotter.launch_LinkSto('radiushealth')
# Out:
# /home/raf/SOFTWARE/anaconda2/envs/py3k6/lib/python3.6/site-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
